# %% [markdown]
# <a href="https://colab.research.google.com/github/Jupiterian/ML-Learning-Portfolio/blob/main/Linear%20Algebra/LinearRegressionGaussianElimination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regressions with Gaussian Elimination
# The following notebook explores Linear Regressions but instead of using a Gradient Descent Algorithm, it relies on Gaussian Elimination.
#
# This serves more as a proof of concept than an actual practical use case.

# %% [markdown]
# The LinearRegression class below is trying to find a solution to the linear system $Xw=y$ where $X$ and $y$ and matricies and $w$ is a column vector for weights. While this is for a linear scenario, the advantage of Gaussian Elimination is that this can be applied to systems with many more features (or weights).

# %%
class LinearRegression():
  def __init__(self):
     pass
  def fit(self, X, y):
