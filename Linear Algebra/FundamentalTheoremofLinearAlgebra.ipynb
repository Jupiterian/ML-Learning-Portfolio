# %% [markdown]
# <a href="https://colab.research.google.com/github/Jupiterian/ML-Learning-Portfolio/blob/main/Linear%20Algebra/FundamentalTheoremofLinearAlgebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fundamental Theorem of Linear Algebra
#
# The Fundamental Theorem of Linear Algebra defines the four fundamental subspaces: column spaces, row spaces, nullspaces, and left nullspaces. This notebook aims to define and find the dimension of each of these subspaces, provided a matrix.

# %% [markdown]
# ## Definiton
# The Fundamental Theorem of Linear Algebra states that given an matrix $A$ of shape $m × n$:
#  - The Column Space of $A$ is defined in $\mathbb{R}^m$ and has a dimension of the matrix rank $r$.
#  - The Row Space of $A$ (also the columns pace of $A^T$ is) is defined in $\mathbb{R}^n$ and has a dimension of $r$.
#  - The Nullspace of $A$ is defined in $\mathbb{R}^n$ and has a dimension of $n-r$.
#  - The left Nullspace of $A$ is defined in $\mathbb{R}^m$ and has a dimension of $n-r$.

# %% [markdown]
# One final note, linear algebra usually defines the row space as the column space of $A^T$, but because numpy is easier to work with in rows, I will be defining the column space as the row space of $A^T$.

# %%
# Chose matrix for testing
import numpy as np
matrix = np.array([[0, 1], [1, 0]])
matrix.shape
# Out:
# (2, 2)

# %%
class Fundamentals():
  def __init__(self):
    pass

  def columnSpace(self, X):
    columns = X.shape
    transposed = np.linalg.matrix_transpose(X)

    for i in transposed:
